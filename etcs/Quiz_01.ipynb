# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/SeoulTechPSE/EngMath/etcs/blob/master/Quiz_01.ipynb)

# %% [markdown]
# ## Quiz

# %% [markdown]
# Find the solution of the initial-boundary value problem:
#
# >$\begin{align*}
#  &u_t = u_{xx} +f(x,t), \;\; 0 \leq x \leq L, \;\; 0 \leq t \\
#  &u(0,t) = 0\\
#  &u(L,t) = 0\\
#  &u(x,0) = \phi(x)
# \end{align*}$

# %% [markdown]
# **Solution**

# %% [markdown]
# >$\begin{align*}
#  &\;\;\;\;\Downarrow {\scriptstyle \text{Superposition Principle}} \\
#  &v_t = v_{xx}, \;\; 0 \leq x \leq L, \;\; 0 \leq t \\
#  &v(0,t) = 0\\
#  &v(L,t) = 0\\
#  &v(x,0) = \phi(x) \\
#  &\;\;\;\;+ \\
#  &w_t = w_{xx} +f(x,t), \;\; 0 \leq x \leq L, \;\; 0 \leq t \\
#  &w(0,t) = 0\\
#  &w(L,t) = 0\\
#  &w(x,0) = 0\\
#  &\;\;\;\;\Downarrow\\
#  &u(x,t) = v(x,t) +w(x,t)\\
# \end{align*}$

# %% [markdown]
# where
#
# >$\begin{align*}
#  v(x,t) &= \sum_{n=1}^\infty a_n \sin\frac{n\pi x}{L}, \;\;a_n = \frac{2}{L} \int_0^L \phi(x) \sin \frac{n\pi x}{L}\,dx \\
#  w(x,t) &= \sum_{n=1}^\infty W_n(t) \sin\frac{n\pi x}{L}, \;\;
#   W_n(t) =\int_0^t \exp \left[-\left( \frac{n\pi}{L} \right)^2 (t -\tau)  \right] f_n(\tau) \,d\tau, \;\;
#   f_n(t) = \frac{2}{L} \int_0^L f(x, t) \sin \frac{n\pi x}{L}\,dx
# \end{align*}$
